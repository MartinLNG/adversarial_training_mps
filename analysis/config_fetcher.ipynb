# %%
# Path setup - run this FIRST before any other imports
import sys
from pathlib import Path

# Add project root to path (notebook is in analysis/)
project_root = Path.cwd().parent
if not (project_root / "src").exists():
    project_root = Path.cwd()

sys.path.insert(0, str(project_root))
print(f"Project root: {project_root}")
# Out:
# Project root: /home/ubuntu/adversarial_training_mps

# %%
from analysis.utils import print_classification_config_yaml

# %%
print_classification_config_yaml(entity="martin-nissen-gonzalez-heidelberg-university",
                            project="gan_train",
                            group="lr_hpo_spirals_4k_23Jan26")
# Out:
# # Best classification config from W&B
# # Group: lr_hpo_spirals_4k_23Jan26
# # Run ID: dvehllwh
# # Run Name: job12/12_D18-d30pre500
# # Valid Acc: 0.9985
# # Test Acc: 0.997
# # Tracking seed: 2
# # Dataset: spirals_4k
# # Dataset split_seed: 11
# # Dataset gen seed: 25
#
# tracking:
#   seed: 2
#
# dataset:
#   split_seed: 11
#   gen_dow_kwargs:
#     seed: 25
#
# trainer:
#   classification:
#     max_epoch: 500
#     batch_size: 64
#     patience: 250
#     stop_crit: "clsloss"
#     watch_freq: 1000
#     save: false
#     optimizer:
#       name: "adam"
#       kwargs:
#         lr: 0.007705829890219126
#         weight_decay: 0
#     criterion:
#       name: "negative log-likelihood"
#       kwargs:
#         eps: 1e-08
#     metrics: {'acc': 1, 'fid': 50, 'rob': 50, 'viz': 50, 'clsloss': 1}
#
# born:
#   init_kwargs:
#     in_dim: 30
#     bond_dim: 18
#     boundary: obc
#     init_method: randn_eye
#     std: 1e-09
#   embedding: "fourier"
